# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib
print(matplotlib.__version__)
# Out:
# 3.10.0

# %%
df = pd.read_csv("customer_master.csv")

# %%
df
# Out:
#   customer_id   customer_name  age gender       city state customer_segment
# 0       C1001    Ramesh Patil   34      M       Pune    MH       Individual
# 1       C1002    Sneha Sharma   29      F     Mumbai    MH       Individual
# 2       C1003      Amit Verma   41      M      Delhi    DL        Corporate
# 3       C1004       Neha Iyer   36      F  Bengaluru    KA       Individual
# 4       C1005      Suresh Rao   52      M  Hyderabad    TS           Senior
# 5       C1006      Priya Nair   31      F      Kochi    KL       Individual
# 6       C1007     Rahul Mehta   45      M  Ahmedabad    GJ        Corporate
# 7       C1008    Kavita Singh   38      F     Jaipur    RJ       Individual
# 8       C1009      Anil Desai   60      M       Pune    MH           Senior
# 9       C1010  Pooja Kulkarni   27      F     Nagpur    MH       Individual

# %%
df.info
# Out:
# <bound method DataFrame.info of   customer_id   customer_name  age gender       city state customer_segment
# 0       C1001    Ramesh Patil   34      M       Pune    MH       Individual
# 1       C1002    Sneha Sharma   29      F     Mumbai    MH       Individual
# 2       C1003      Amit Verma   41      M      Delhi    DL        Corporate
# 3       C1004       Neha Iyer   36      F  Bengaluru    KA       Individual
# 4       C1005      Suresh Rao   52      M  Hyderabad    TS           Senior
# 5       C1006      Priya Nair   31      F      Kochi    KL       Individual
# 6       C1007     Rahul Mehta   45      M  Ahmedabad    GJ        Corporate
# 7       C1008    Kavita Singh   38      F     Jaipur    RJ       Individual
# 8       C1009      Anil Desai   60      M       Pune    MH           Senior
# 9       C1010  Pooja Kulkarni   27      F     Nagpur    MH       Individual>

# %%
df.describe()
# Out:
#              age
# count  10.000000
# mean   39.300000
# std    10.499206
# min    27.000000
# 25%    31.750000
# 50%    37.000000
# 75%    44.000000
# max    60.000000

# %%
df.isnull().sum()
# Out:
# customer_id         0
# customer_name       0
# age                 0
# gender              0
# city                0
# state               0
# customer_segment    0
# dtype: int64

# %%
df['gender'].value_counts()
# Out:
# gender
# M    5
# F    5
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6,5))
df['gender'].value_counts().plot(kind='bar')
plt.title('Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Counts')
plt.show()

# %%
plt.figure(figsize=(6,6))

df['customer_segment'].value_counts().plot(
    kind='pie',
    autopct='%1.1f%%'
)

plt.title("Customer Segment Distribution")
plt.ylabel("customer")

plt.show()

# %%
plt.figure(figsize=(6,5))
plt.hist(df['age'],bins=10)
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('frequency')
plt.show()

# %%
plt.figure(figsize=(6,5))
df['state'].value_counts().plot(kind='bar')
plt.title('Customer By States')
plt.xlabel('State')
plt.ylabel('No. of customers')
plt.xticks(rotation=360)
plt.show()

# %%
plt.figure(figsize=(6,5))
sns.boxplot(x='gender',y='age',data=df)
plt.title('age Distribution By Gender')
plt.show()
